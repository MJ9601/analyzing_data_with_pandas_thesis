# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
fff = pd.read_csv('fff.out', sep=' ')
fff1 = pd.read_csv('fff1.out', sep=' ')
fff2 = pd.read_csv('fff2.out', sep=' ')
fff3 = pd.read_csv('fff3.out', sep=' ')
fff4 = pd.read_csv('fff4.out', sep=' ')
fff5 = pd.read_csv('fff5.out', sep=' ')
fff6 = pd.read_csv('fff6.out', sep=' ')
fff7 = pd.read_csv('fff7.out', sep=' ')
fff8 = pd.read_csv('fff8.out', sep=' ')
fff9 = pd.read_csv('fff9.out', sep=' ')
fff10 = pd.read_csv('fff10.out', sep=' ')
fff11 = pd.read_csv('fff11.out', sep=' ')
detial = pd.read_csv('detials.txt')

# %%
fff['electrical-efficiency'] = 14*(1-0.0045*(fff['pv-temp'] - 298.15))
fff1['electrical-efficiency'] = 14*(1-0.0045*(fff1['pv-temp'] - 298.15))
fff2['electrical-efficiency'] = 14*(1-0.0045*(fff2['pv-temp'] - 298.15))
fff3['electrical-efficiency'] = 14*(1-0.0045*(fff3['pv-temp'] - 298.15))
fff4['electrical-efficiency'] = 14*(1-0.0045*(fff4['pv-temp'] - 298.15))
fff5['electrical-efficiency'] = 14*(1-0.0045*(fff5['pv-temp'] - 298.15))
fff6['electrical-efficiency'] = 14*(1-0.0045*(fff6['pv-temp'] - 298.15))
fff7['electrical-efficiency'] = 14*(1-0.0045*(fff7['pv-temp'] - 298.15))
fff8['electrical-efficiency'] = 14*(1-0.0045*(fff8['pv-temp'] - 298.15))
fff9['electrical-efficiency'] = 14*(1-0.0045*(fff9['pv-temp'] - 298.15))
fff10['electrical-efficiency'] = 14*(1-0.0045*(fff10['pv-temp'] - 298.15))
fff11['electrical-efficiency'] = 14*(1-0.0045*(fff11['pv-temp'] - 298.15))

# %%
fff
# Out:
#      Time Step  flow-time  delta-time  iters-per-timestep  melting-francion  \
# 0            0          0         100                  28          0.000000
# 1            1        100         100                  40          0.000000
# 2            2        200         100                  40          0.000000
# 3            3        300         100                  40          0.000000
# 4            4        400         100                  40          0.000000
# ..         ...        ...         ...                 ...               ...
# 104        104      10400         100                   7          0.832672
# 105        105      10500         100                   7          0.837060
# 106        106      10600         100                   7          0.841280
# 107        107      10700         100                   7          0.845334
# 108        108      10800         100                   7          0.849257
#
# ...

# %% [markdown]
# print(plt.style.available)

# %%
fig,(axis1, axis2, axis3, axis4, axis5)= plt.subplots(figsize=(10,25) ,nrows=5, ncols=1, sharex=True)
# seting the plot data
axis1.plot(fff['flow-time'], fff['melting-francion'], label='1000 W/m^2')
axis1.plot(fff8['flow-time'], fff8['melting-francion'], label='800 W/m^2')
axis1.plot(fff9['flow-time'], fff9['melting-francion'], label='600 W/m^2')

axis2.plot(fff['flow-time'], fff['outlet-temp'], label='1000 W/m^2')
axis2.plot(fff8['flow-time'], fff8['outlet-temp'], label='800 W/m^2')
axis2.plot(fff9['flow-time'], fff9['outlet-temp'], label='600 W/m^2')

axis3.plot(fff['flow-time'], fff['pcm-temp'], label='1000 W/m^2')
axis3.plot(fff8['flow-time'], fff8['pcm-temp'], label='800 W/m^2')
axis3.plot(fff9['flow-time'], fff9['pcm-temp'], label='600 W/m^2')

axis4.plot(fff['flow-time'], fff['pv-temp'], label='1000 W/m^2')
axis4.plot(fff8['flow-time'], fff8['pv-temp'], label='800 W/m^2')
axis4.plot(fff9['flow-time'], fff9['pv-temp'], label='600 W/m^2')

axis5.plot(fff['flow-time'], fff['electrical-efficiency'], label='1000 W/m^2')
axis5.plot(fff8['flow-time'], fff8['electrical-efficiency'], label='800 W/m^2')
axis5.plot(fff9['flow-time'], fff9['electrical-efficiency'], label='600 W/m^2')

# setting the legned of plots
axis1.legend(prop={"family":"Times New Roman"}, frameon=False)
axis2.legend(prop={"family":"Times New Roman"}, frameon=False)
axis3.legend(prop={"family":"Times New Roman"}, frameon=False)
axis4.legend(prop={"family":"Times New Roman"}, frameon=False)
axis5.legend(prop={"family":"Times New Roman"}, frameon=False)

# setting x and y labels and their font and fontsize
axis1.set_ylabel('Melting Fraction',fontname='Times New Roman', fontsize=12)
axis2.set_ylabel('Outlet Temperature (K)',fontname='Times New Roman', fontsize=12)
axis3.set_ylabel('PCM Temperature (K)',fontname='Times New Roman', fontsize=12)
axis4.set_ylabel('PV Temperature (K)',fontname='Times New Roman', fontsize=12)
axis5.set_ylabel('Electrical Efficiency',fontname='Times New Roman', fontsize=12)
plt.xlabel('Time (s)',fontname='Times New Roman', fontsize=12)


# setting x and y tick
for tick in axis1.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)
for tick in axis2.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)
for tick in axis3.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)
for tick in axis4.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)
for tick in axis5.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)

for tick in axis5.get_xticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)

plt.savefig('different irradiation.png')

# %%
fff2
# Out:
#      Time Step  flow-time  delta-time  iters-per-timestep  melting-fraction  \
# 0            0          0         100                   0          0.000000
# 1            1        100         100                  40          0.000000
# 2            2        200         100                  40          0.000000
# 3            3        300         100                  40          0.000000
# 4            4        400         100                  40          0.000000
# ..         ...        ...         ...                 ...               ...
# 104        104      10400         100                   7          0.764128
# 105        105      10500         100                   7          0.769198
# 106        106      10600         100                   7          0.774155
# 107        107      10700         100                   7          0.779004
# 108        108      10800         100                   7          0.783763
#
# ...

# %%
fig,(axis1, axis2, axis3, axis4, axis5)= plt.subplots(figsize=(10,25) ,nrows=5, ncols=1, sharex=True)
# seting the plot data
axis1.plot(fff['flow-time'], fff['melting-francion'], label='Y Shape fins, Model 1')
axis1.plot(fff1['flow-time'], fff1['melitng-fraction'], label='Y Shape fins, Model 2')
axis1.plot(fff2['flow-time'], fff2['melting-fraction'], label='Y Shape fins, Model 3')

axis2.plot(fff['flow-time'], fff['outlet-temp'], label='Y Shape fins, Model 1')
axis2.plot(fff1['flow-time'], fff1['outlet-temp'], label='Y Shape fins, Model 2')
axis2.plot(fff2['flow-time'], fff2['outlet-temp'], label='Y Shape fins, Model 3')

axis3.plot(fff['flow-time'], fff['pcm-temp'], label='Y Shape fins, Model 1')
axis3.plot(fff1['flow-time'], fff1['pcm-temp'], label='Y Shape fins, Model 2')
axis3.plot(fff2['flow-time'], fff2['pcm-temp'], label='Y Shape fins, Model 3')

axis4.plot(fff['flow-time'], fff['pv-temp'], label='Y Shape fins, Model 1')
axis4.plot(fff1['flow-time'], fff1['pv-temp'], label='Y Shape fins, Model 2')
axis4.plot(fff2['flow-time'], fff2['pv-temp'], label='Y Shape fins, Model 3')

axis5.plot(fff['flow-time'], fff['electrical-efficiency'], label='Y Shape fins, Model 1')
axis5.plot(fff1['flow-time'], fff1['electrical-efficiency'], label='Y Shape fins, Model 2')
axis5.plot(fff2['flow-time'], fff2['electrical-efficiency'], label='Y Shape fins, Model 3')

# setting the legned of plots
axis1.legend(prop={"family":"Times New Roman"}, frameon=False)
axis2.legend(prop={"family":"Times New Roman"}, frameon=False)
axis3.legend(prop={"family":"Times New Roman"}, frameon=False)
axis4.legend(prop={"family":"Times New Roman"}, frameon=False)
axis5.legend(prop={"family":"Times New Roman"}, frameon=False)

# setting x and y labels and their font and fontsize
axis1.set_ylabel('Melting Fraction',fontname='Times New Roman', fontsize=12)
axis2.set_ylabel('Outlet Temperature (K)',fontname='Times New Roman', fontsize=12)
axis3.set_ylabel('PCM Temperature (K)',fontname='Times New Roman', fontsize=12)
axis4.set_ylabel('PV Temperature (K)',fontname='Times New Roman', fontsize=12)
axis5.set_ylabel('Electrical Efficiency',fontname='Times New Roman', fontsize=12)
plt.xlabel('Time (s)',fontname='Times New Roman', fontsize=12)


# setting x and y tick
for tick in axis1.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)
for tick in axis2.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)
for tick in axis3.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)
for tick in axis4.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)
for tick in axis5.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)

for tick in axis5.get_xticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)

plt.savefig('different type of.png')

# %%
fig,(axis1, axis2, axis3, axis4, axis5)= plt.subplots(figsize=(10,25) ,nrows=5, ncols=1, sharex=True)
# seting the plot data
axis1.plot(fff['flow-time'], fff['melting-francion'], label='4vl% NePCM')
axis1.plot(fff3['flow-time'], fff3['melting-francion'], label='2vl% NePCM')
axis1.plot(fff4['flow-time'], fff4['melting-francion'], label='0vl% NePCM')

axis2.plot(fff['flow-time'], fff['outlet-temp'], label='4vl% NePCM')
axis2.plot(fff3['flow-time'], fff3['outlet-temp'], label='2vl% NePCM')
axis2.plot(fff4['flow-time'], fff4['outlet-temp'], label='0vl% NePCM')

axis3.plot(fff['flow-time'], fff['pcm-temp'], label='4vl% NePCM')
axis3.plot(fff3['flow-time'], fff3['pcm-temp'], label='2vl% NePCM')
axis3.plot(fff4['flow-time'], fff4['pcm-temp'], label='0vl% NePCM')

axis4.plot(fff['flow-time'], fff['pv-temp'], label='4vl% NePCM')
axis4.plot(fff3['flow-time'], fff3['pv-temp'], label='2vl% NePCM')
axis4.plot(fff4['flow-time'], fff4['pv-temp'], label='0vl% NePCM')

axis5.plot(fff['flow-time'], fff['electrical-efficiency'], label='4vl% NePCM')
axis5.plot(fff3['flow-time'], fff3['electrical-efficiency'], label='2vl% NePCM')
axis5.plot(fff4['flow-time'], fff4['electrical-efficiency'], label='0vl% NePCM')

# setting the legned of plots
axis1.legend(prop={"family":"Times New Roman"}, frameon=False)
axis2.legend(prop={"family":"Times New Roman"}, frameon=False)
axis3.legend(prop={"family":"Times New Roman"}, frameon=False)
axis4.legend(prop={"family":"Times New Roman"}, frameon=False)
axis5.legend(prop={"family":"Times New Roman"}, frameon=False)

# setting x and y labels and their font and fontsize
axis1.set_ylabel('Melting Fraction',fontname='Times New Roman', fontsize=12)
axis2.set_ylabel('Outlet Temperature (K)',fontname='Times New Roman', fontsize=12)
axis3.set_ylabel('PCM Temperature (K)',fontname='Times New Roman', fontsize=12)
axis4.set_ylabel('PV Temperature (K)',fontname='Times New Roman', fontsize=12)
axis5.set_ylabel('Electrical Efficiency',fontname='Times New Roman', fontsize=12)
plt.xlabel('Time (s)',fontname='Times New Roman', fontsize=12)


# setting x and y tick
for tick in axis1.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)
for tick in axis2.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)
for tick in axis3.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)
for tick in axis4.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)
for tick in axis5.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)

for tick in axis5.get_xticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)

plt.savefig('different vl of NEPCM.png')

# %%
fig,(axis1, axis2, axis3, axis4, axis5)= plt.subplots(figsize=(10,25) ,nrows=5, ncols=1, sharex=True)
# seting the plot data
axis1.plot(fff7['flow-time'], fff7['melting-francion'], label='6vl% Nanofluid')
axis1.plot(fff['flow-time'], fff['melting-francion'], label='4vl% Nanofluid')
axis1.plot(fff5['flow-time'], fff5['melting-francion'], label='2vl% Nanofluid')
axis1.plot(fff6['flow-time'], fff6['melting-francion'], label='0vl% Nanofluid')

axis2.plot(fff7['flow-time'], fff7['outlet-temp'], label='6vl% Nanofluid')
axis2.plot(fff['flow-time'], fff['outlet-temp'], label='4vl% Nanofluid')
axis2.plot(fff5['flow-time'], fff5['outlet-temp'], label='2vl% Nanofluid')
axis2.plot(fff6['flow-time'], fff6['outlet-temp'], label='0vl% Nanofluid')

axis3.plot(fff7['flow-time'], fff7['pcm-temp'], label='6vl% Nanofluid')
axis3.plot(fff['flow-time'], fff['pcm-temp'], label='4vl% Nanofluid')
axis3.plot(fff5['flow-time'], fff5['pcm-temp'], label='2vl% Nanofluid')
axis3.plot(fff6['flow-time'], fff6['pcm-temp'], label='0vl% Nanofluid')

axis4.plot(fff7['flow-time'], fff7['pv-temp'], label='6vl% Nanofluid')
axis4.plot(fff['flow-time'], fff['pv-temp'], label='4vl% Nanofluid')
axis4.plot(fff5['flow-time'], fff5['pv-temp'], label='2vl% Nanofluid')
axis4.plot(fff6['flow-time'], fff6['pv-temp'], label='0vl% Nanofluid')

axis5.plot(fff7['flow-time'], fff7['electrical-efficiency'], label='6vl% Nanofluid')
axis5.plot(fff['flow-time'], fff['electrical-efficiency'], label='4vl% Nanofluid')
axis5.plot(fff5['flow-time'], fff5['electrical-efficiency'], label='2vl% Nanofluid')
axis5.plot(fff6['flow-time'], fff6['electrical-efficiency'], label='0vl% Nanofluid')

# setting the legned of plots
axis1.legend(prop={"family":"Times New Roman"}, frameon=False)
axis2.legend(prop={"family":"Times New Roman"}, frameon=False)
axis3.legend(prop={"family":"Times New Roman"}, frameon=False)
axis4.legend(prop={"family":"Times New Roman"}, frameon=False)
axis5.legend(prop={"family":"Times New Roman"}, frameon=False)

# setting x and y labels and their font and fontsize
axis1.set_ylabel('Melting Fraction',fontname='Times New Roman', fontsize=12)
axis2.set_ylabel('Outlet Temperature (K)',fontname='Times New Roman', fontsize=12)
axis3.set_ylabel('PCM Temperature (K)',fontname='Times New Roman', fontsize=12)
axis4.set_ylabel('PV Temperature (K)',fontname='Times New Roman', fontsize=12)
axis5.set_ylabel('Electrical Efficiency',fontname='Times New Roman', fontsize=12)
plt.xlabel('Time (s)',fontname='Times New Roman', fontsize=12)


# setting x and y tick
for tick in axis1.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)
for tick in axis2.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)
for tick in axis3.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)
for tick in axis4.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)
for tick in axis5.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)

for tick in axis5.get_xticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)

plt.savefig('different vl of nanofluid.png')

# %%
fig,(axis1, axis2, axis3, axis4, axis5)= plt.subplots(figsize=(10,25) ,nrows=5, ncols=1, sharex=True)
# seting the plot data
axis1.plot(fff['flow-time'], fff['melting-francion'], label='0.1 m/s')
axis1.plot(fff10['flow-time'], fff10['melting-francion'], label='0.15 m/s')
axis1.plot(fff11['flow-time'], fff11['melting-francion'], label='0.2 m/s')

axis2.plot(fff['flow-time'], fff['outlet-temp'], label='0.1 m/s')
axis2.plot(fff10['flow-time'], fff10['outlet-temp'], label='0.15 m/s')
axis2.plot(fff11['flow-time'], fff11['outlet-temp'], label='0.2 m/s')

axis3.plot(fff['flow-time'], fff['pcm-temp'], label='0.1 m/s')
axis3.plot(fff10['flow-time'], fff10['pcm-temp'], label='0.15 m/s')
axis3.plot(fff11['flow-time'], fff11['pcm-temp'], label='0.2 m/s')

axis4.plot(fff['flow-time'], fff['pv-temp'], label='0.1 m/s')
axis4.plot(fff10['flow-time'], fff10['pv-temp'], label='0.15 m/s')
axis4.plot(fff11['flow-time'], fff11['pv-temp'], label='0.2 m/s')

axis5.plot(fff['flow-time'], fff['electrical-efficiency'], label='0.1 m/s')
axis5.plot(fff10['flow-time'], fff10['electrical-efficiency'], label='0.15 m/s')
axis5.plot(fff11['flow-time'], fff11['electrical-efficiency'], label='0.2 m/s')

# setting the legned of plots
axis1.legend(prop={"family":"Times New Roman"}, frameon=False)
axis2.legend(prop={"family":"Times New Roman"}, frameon=False)
axis3.legend(prop={"family":"Times New Roman"}, frameon=False)
axis4.legend(prop={"family":"Times New Roman"}, frameon=False)
axis5.legend(prop={"family":"Times New Roman"}, frameon=False)

# setting x and y labels and their font and fontsize
axis1.set_ylabel('Melting Fraction',fontname='Times New Roman', fontsize=12)
axis2.set_ylabel('Outlet Temperature (K)',fontname='Times New Roman', fontsize=12)
axis3.set_ylabel('PCM Temperature (K)',fontname='Times New Roman', fontsize=12)
axis4.set_ylabel('PV Temperature (K)',fontname='Times New Roman', fontsize=12)
axis5.set_ylabel('Electrical Efficiency',fontname='Times New Roman', fontsize=12)
plt.xlabel('Time (s)',fontname='Times New Roman', fontsize=12)


# setting x and y tick
for tick in axis1.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)
for tick in axis2.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)
for tick in axis3.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)
for tick in axis4.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)
for tick in axis5.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)

for tick in axis5.get_xticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(12)

plt.savefig('different mass flow.png')
